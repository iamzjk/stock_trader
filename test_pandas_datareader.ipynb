# 2017-04-11  11.27  11.28  11.17  11.28   36366316
# 2017-04-12  11.27  11.30  11.20  11.23   56588425
# 2017-04-13  11.22  11.25  11.11  11.11   32789905
# 2017-04-17  11.22  11.30  11.14  11.28   44731735
# 2017-04-18  11.15  11.18  11.08  11.14   35659989
# 2017-04-19  11.19  11.28  11.17  11.19   37524445
# 2017-04-20  11.25  11.50  11.24  11.47   49990191
# 2017-04-21  11.46  11.48  11.32  11.34   26076186
# 2017-04-24  11.48  11.50  11.36  11.43   41071326
# 2017-04-25  11.47  11.50  11.43  11.48   35862521
# 2017-04-26  11.47  11.70  11.45  11.60   51685768
# 2017-04-27  11.66  11.68  11.34  11.47   50203741
# 2017-04-28  11.51  11.51  11.40  11.47   41415145
# 2017-05-01  11.49  11.54  11.40  11.42   32118379
#
# [3355 rows x 5 columns]

# %%
# args: symbols, 
aapl = web.DataReader(['AAPL', 'F'], 'google', start, end)

# %%
aapl.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
dir(aapl)
# Out:
# ['Close',
#  'High',
#  'Low',
#  'Open',
#  'Volume',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_aggregate_operations',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_align_frame',
#  '_align_series',
#  '_apply_1d',
#  '_apply_2d',
#  '_at',
#  '_box_item_values',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_combine',
#  '_combine_const',
#  '_combine_frame',
#  '_combine_panel',
#  '_compare_constructor',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_for_slice',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_construct_return_type',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_create_indexer',
#  '_dir_additions',
#  '_dir_deletions',
#  '_expand_axes',
#  '_extract_axes',
#  '_extract_axes_for_slice',
#  '_extract_axis',
#  '_from_axes',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_join_index',
#  '_get_numeric_data',
#  '_get_plane_axes',
#  '_get_plane_axes_index',
#  '_get_values',
#  '_getitem_multilevel',
#  '_homogenize_dict',
#  '_iat',
#  '_iget_item_cache',
#  '_iloc',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_arrays',
#  '_init_data',
#  '_init_dict',
#  '_init_matrix',
#  '_init_mgr',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_cached',
#  '_is_datelike_mixed_type',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_loc',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_prep_ndarray',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_axis',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_reset_cache',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_is_copy',
#  '_set_item',
#  '_setup_axes',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_typ',
#  '_unpickle_panel_compat',
#  '_update_inplace',
#  '_validate_dtype',
#  '_wrap_result',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'align',
#  'all',
#  'any',
#  'apply',
#  'as_blocks',
#  'as_matrix',
#  'asfreq',
#  'astype',
#  'at',
#  'at_time',
#  'axes',
#  'between_time',
#  'bfill',
#  'blocks',
#  'bool',
#  'clip',
#  'clip_lower',
#  'clip_upper',
#  'compound',
#  'conform',
#  'consolidate',
#  'convert_objects',
#  'copy',
#  'count',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'div',
#  'divide',
#  'drop',
#  'dropna',
#  'dtypes',
#  'empty',
#  'eq',
#  'equals',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'floordiv',
#  'fromDict',
#  'from_dict',
#  'ftypes',
#  'ge',
#  'get',
#  'get_dtype_counts',
#  'get_ftype_counts',
#  'get_value',
#  'get_values',
#  'groupby',
#  'gt',
#  'head',
#  'iat',
#  'iloc',
#  'interpolate',
#  'is_copy',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterkv',
#  'ix',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'le',
#  'load',
#  'loc',
#  'lt',
#  'mad',
#  'major_axis',
#  'major_xs',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'minor_axis',
#  'minor_xs',
#  'mod',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'notnull',
#  'pct_change',
#  'pipe',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'radd',
#  'rdiv',
#  'reindex',
#  'reindex_axis',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'replace',
#  'resample',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'save',
#  'select',
#  'sem',
#  'set_axis',
#  'set_value',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'squeeze',
#  'std',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'toLong',
#  'to_clipboard',
#  'to_dense',
#  'to_excel',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_long',
#  'to_msgpack',
#  'to_pickle',
#  'to_sparse',
#  'to_sql',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'update',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
aapl.Close
# Out:
#               AAPL      F
# Date
# 2004-01-02    1.52  16.08
# 2004-01-05    1.58  16.59
# 2004-01-06    1.58  16.54
# 2004-01-07    1.61  16.99
# 2004-01-08    1.67  17.10
# 2004-01-09    1.64  16.56
# 2004-01-12    1.70  16.41
# 2004-01-13    1.72  16.28
# 2004-01-14    1.73  16.18
# 2004-01-15    1.63  16.05
# 2004-01-16    1.62  16.13
# 2004-01-20    1.62  16.21
# 2004-01-21    1.62  16.44
# 2004-01-22    1.58  16.43
# 2004-01-23    1.61  15.83
# 2004-01-26    1.64  15.96
# 2004-01-27    1.65  15.94
# 2004-01-28    1.61  15.58
# 2004-01-29    1.62  14.84
# 2004-01-30    1.61  14.54
# 2004-02-02    1.59  13.95
# 2004-02-03    1.59  13.72
# 2004-02-04    1.56  13.89
# 2004-02-05    1.60  14.15
# 2004-02-06    1.62  14.28
# 2004-02-09    1.62  14.16
# 2004-02-10    1.64  14.39
# 2004-02-11    1.70  14.64
# 2004-02-12    1.70  14.55
# 2004-02-13    1.64  14.36
# ...            ...    ...
# 2017-03-20  141.46  12.28
# 2017-03-21  139.84  11.72
# 2017-03-22  141.42  11.77
# 2017-03-23  140.92  11.67
# 2017-03-24  140.64  11.62
# 2017-03-27  140.88  11.46
# 2017-03-28  143.80  11.65
# 2017-03-29  144.12  11.68
